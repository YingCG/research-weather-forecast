# %%
import numpy as np
import pandas as pd
rain = pd.read_csv('data/statsNZ/rainfall-data-to-2022-statsnz/daily-rainfall-at-30-sites-1960-to-2022.csv')
drought = pd.read_csv('data/statsNZ/drought-data-to-2022-statsnz/drought-spei-1962-2022.csv')
extreme = pd.read_csv('data/statsNZ/extreme-rainfall-data-to-2022-statsnz/extreme-rainfall-1960-to-2022.csv')

# %%
rain.head()
# Out:
#                   site        date  rainfall rainfall_units       lat  \
# 0  Auckland (Auckland)  1960-01-01       0.0             mm -37.00813
# 1  Auckland (Auckland)  1960-01-02       0.0             mm -37.00813
# 2  Auckland (Auckland)  1960-01-03       9.2             mm -37.00813
# 3  Auckland (Auckland)  1960-01-04       0.0             mm -37.00813
# 4  Auckland (Auckland)  1960-01-05       0.0             mm -37.00813
#
#          lon
# 0  174.78873
# 1  174.78873
# 2  174.78873
# 3  174.78873
# 4  174.78873

# %%
drought.head()
# Out:
#                   site  id  year  month  time_scale          drought_type  \
# 0  Auckland (Auckland)   1  1966     12          12  Hydrological drought
# 1  Auckland (Auckland)   1  1967      1          12  Hydrological drought
# 2  Auckland (Auckland)   1  1967      2          12  Hydrological drought
# 3  Auckland (Auckland)   1  1967      3          12  Hydrological drought
# 4  Auckland (Auckland)   1  1967      4          12  Hydrological drought
#
#        spei    spei_class  imputed_value      drought_event  duration  \
# 0  1.393009  Moderate wet          False  Non-drought event       NaN
# 1  1.303403  Moderate wet          False  Non-drought event       NaN
# 2  1.450834  Moderate wet          False  Non-drought event       NaN
# 3  2.206351   Extreme wet          False  Non-drought event       NaN
# 4  1.932205    Severe wet          False  Non-drought event       NaN
#
#   start_event  severity  intensity       lat        lon    region
# ...

# %%
extreme.head()
# Out:
#                   site period_start  period_end reference_period  \
# 0  Auckland (Auckland)   2022-01-01  2022-12-31              NaN
# 1  Auckland (Auckland)   2022-01-01  2022-12-31        1961-1990
# 2  Auckland (Auckland)   2022-01-01  2022-12-31        1961-1990
# 3  Auckland (Auckland)   2022-01-01  2022-12-31        1991-2020
# 4  Auckland (Auckland)   2022-01-01  2022-12-31        1991-2020
#
#                        parameter  data_value       lat        lon
# 0       Maximum one-day rainfall   62.800000 -37.00813  174.78873
# 1                  Very wet days   10.000000 -37.00813  174.78873
# 2  Rainfall due to very wet days   30.083857 -37.00813  174.78873
# 3                  Very wet days   11.000000 -37.00813  174.78873
# 4  Rainfall due to very wet days   32.180294 -37.00813  174.78873

# %%
rain['site'].value_counts()
# Out:
# Auckland (Auckland)                23011
# Blenheim (Marlborough)             23011
# Whangaparāoa (Auckland)            23011
# Whanganui (Manawatū-Whanganui)     23011
# Wellington (Wellington)            23011
# Waiouru (Manawatū-Whanganui)       23011
# Timaru (Canterbury)                23011
# Tauranga (Bay of Plenty)           23011
# Taupō (Waikato)                    23011
# Taumarunui (Manawatū-Whanganui)    23011
# Tara Hills (Canterbury)            23011
# Rotorua (Bay of Plenty)            23011
# Reefton (West Coast)               23011
# Queenstown (Otago)                 23011
# New Plymouth (Taranaki)            23011
# Nelson (Nelson)                    23011
# Napier (Hawke's Bay)               23011
# Milford Sound (Southland)          23011
# Masterton (Wellington)             23011
# Lake Tekapo (Canterbury)           23011
# Kerikeri (Northland)               23011
# Invercargill (Southland)           23011
# Hokitika (West Coast)              23011
# ...
