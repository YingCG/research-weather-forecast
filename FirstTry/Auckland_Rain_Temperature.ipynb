# %%
import numpy as np
import pandas as pd
noaaNZ = pd.read_csv('data/NOAAdata/NzNoaa_3485743.csv', parse_dates=['DATE'])
rain = pd.read_csv('data/statsNZ/rainfall-data-to-2022-statsnz/daily-rainfall-at-30-sites-1960-to-2022.csv', parse_dates=['date'])
temperature1 = pd.read_csv('data/statsNZ/temperature-data-to-2022-statsnz/daily-temperature-for-30-sites-to-2022-part1.csv', parse_dates=['date'])
temperature2 = pd.read_csv('data/statsNZ/temperature-data-to-2022-statsnz/daily-temperature-for-30-sites-to-2022-part2.csv', parse_dates=['date'])
temperature3 = pd.read_csv('data/statsNZ/temperature-data-to-2022-statsnz/daily-temperature-for-30-sites-to-2022-part3.csv', parse_dates=['date'])
noaaNZ.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\yingg\research-weather-forecast\FirstTry\Auckland_Rain_Temperature.ipynb Cell 1 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/yingg/research-weather-forecast/FirstTry/Auckland_Rain_Temperature.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import numpy as np
#       <a href='vscode-notebook-cell:/c%3A/Users/yingg/research-weather-forecast/FirstTry/Auckland_Rain_Temperature.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/yingg/research-weather-forecast/FirstTry/Auckland_Rain_Temperature.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> noaaNZ = pd.read_csv('data/NOAAdata/NzNoaa_3485743.csv', parse_dates=['DATE'])
#       <a href='vscode-notebook-cell:/c%3A/Users/yingg/research-weather-forecast/FirstTry/Auckland_Rain_Temperature.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> rain = pd.read_csv('data/statsNZ/rainfall-data-to-2022-statsnz/daily-rainfall-at-30-sites-1960-to-2022.csv', parse_dates=['date'])
#       <a href='vscode-notebook-cell:/c%3A/Users/yingg/research-weather-forecast/FirstTry/Auckland_Rain_Temperature.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> temperature1 = pd.read_csv('data/statsNZ/temperature-data-to-2022-statsnz/daily-temperature-for-30-sites-to-2022-part1.csv', parse_dates=['date'])
#
# File c:\Python310\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Python310\lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Python310\lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Python310\lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File c:\Python310\lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/NOAAdata/NzNoaa_3485743.csv'

# %%
noaaNZ.head()
# Out:
#        STATION                    NAME       DATE  PRCP  SNWD  TAVG  TMAX  \
# 0  NZ000093994  RAOUL ISL KERMADEC, NZ 1960-03-05   NaN   NaN  69.0  75.0
# 1  NZ000093994  RAOUL ISL KERMADEC, NZ 1960-03-06   NaN   NaN  71.0  74.0
# 2  NZ000093994  RAOUL ISL KERMADEC, NZ 1960-03-07   NaN   NaN  72.0  75.0
# 3  NZ000093994  RAOUL ISL KERMADEC, NZ 1960-03-08   NaN   NaN  72.0  75.0
# 4  NZ000093994  RAOUL ISL KERMADEC, NZ 1960-03-09   NaN   NaN  73.0  75.0
#
#    TMIN
# 0  65.0
# 1  67.0
# 2  70.0
# 3  69.0
# 4  69.0

# %%
noaaNZ.tail()
# Out:
#             STATION                    NAME       DATE  PRCP  SNWD  TAVG  \
# 226923  NZ000093292  GISBORNE AERODROME, NZ 2023-09-30  0.25   NaN  48.0
# 226924  NZ000093292  GISBORNE AERODROME, NZ 2023-10-01  0.00   NaN  59.0
# 226925  NZ000093292  GISBORNE AERODROME, NZ 2023-10-02  0.05   NaN  60.0
# 226926  NZ000093292  GISBORNE AERODROME, NZ 2023-10-03  0.10   NaN  49.0
# 226927  NZ000093292  GISBORNE AERODROME, NZ 2023-10-04  0.00   NaN  50.0
#
#         TMAX  TMIN
# 226923   NaN  40.0
# 226924   NaN  40.0
# 226925  74.0  48.0
# 226926  61.0  45.0
# 226927   NaN  40.0

# %%
noaaNZ['NAME'].value_counts()
# Out:
# NEW PLYMOUTH AWS, NZ              23190
# INVERCARGILL AIRPOR, NZ           23187
# RAOUL ISL KERMADEC, NZ            22816
# GISBORNE AERODROME, NZ            22499
# CHRISTCHURCH INTERNATIONAL, NZ    22036
# HOKITIKA AERODROME, NZ            21799
# KAITAIA, NZ                       19963
# PARAPARAUMU AWS, NZ               18882
# CHATHAM ISLANDS AWS, NZ           16251
# TARA HILLS, NZ                    15984
# AUCKLAND AERO AWS, NZ             10605
# KAIKOURA, NZ                       9716
# Name: NAME, dtype: int64

# %%
aucklandNoaa = noaaNZ[noaaNZ['NAME'] == 'AUCKLAND AERO AWS, NZ']
aucklandNoaa.rename(columns={"DATE": 'date', "PRCP" : 'precipitation', "TAVG" : 'tavg', 'TMAX': 'tmax', 'TMIN': 'tmin' }, inplace=True)
aucklandNoaa
# Out:
# C:\Users\Ying\AppData\Local\Temp\ipykernel_16288\3332883279.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aucklandNoaa.rename(columns={"DATE": 'date', "PRCP" : 'precipitation', "TAVG" : 'tavg', 'TMAX': 'tmax', 'TMIN': 'tmin' }, inplace=True)
#             STATION                   NAME       date  precipitation  SNWD  \
# 129719  NZM00093110  AUCKLAND AERO AWS, NZ 1994-08-02            NaN   NaN
# 129720  NZM00093110  AUCKLAND AERO AWS, NZ 1994-08-03            NaN   NaN
# 129721  NZM00093110  AUCKLAND AERO AWS, NZ 1994-08-04           0.00   NaN
# 129722  NZM00093110  AUCKLAND AERO AWS, NZ 1994-08-05           0.02   NaN
# 129723  NZM00093110  AUCKLAND AERO AWS, NZ 1994-08-06           0.00   NaN
# ...             ...                    ...        ...            ...   ...
# 140319  NZM00093110  AUCKLAND AERO AWS, NZ 2023-09-30           0.05   NaN
# 140320  NZM00093110  AUCKLAND AERO AWS, NZ 2023-10-01           0.00   NaN
# 140321  NZM00093110  AUCKLAND AERO AWS, NZ 2023-10-02           0.17   NaN
# 140322  NZM00093110  AUCKLAND AERO AWS, NZ 2023-10-03           0.00   NaN
# 140323  NZM00093110  AUCKLAND AERO AWS, NZ 2023-10-04           0.00   NaN
#
#         tavg  tmax  tmin
# 129719  56.0   NaN   NaN
# 129720  55.0   NaN   NaN
# 129721  52.0   NaN   NaN
# 129722  54.0   NaN   NaN
# 129723  53.0   NaN   NaN
# ...      ...   ...   ...
# 140319  54.0   NaN  47.0
# 140320  58.0   NaN  51.0
# 140321  58.0  65.0  53.0
# 140322  52.0  61.0  41.0
# 140323  56.0  60.0  41.0
#
# [10605 rows x 8 columns]

# %%
filepath = 'data/aucklandNoaa.csv'
aucklandNoaa.to_csv(filepath, index=False)

# %%
aucklandTemp = temperature1[temperature1['site'] == 'Auckland (Auckland)']
aucklandTemp
# Out:
#                       site       date statistic  temperature       lat  \
# 0      Auckland (Auckland) 1966-01-01   Maximum         22.2 -37.00813
# 1      Auckland (Auckland) 1966-01-01   Minimum         13.9 -37.00813
# 2      Auckland (Auckland) 1966-01-01   Average         18.0 -37.00813
# 3      Auckland (Auckland) 1966-01-02   Maximum         23.9 -37.00813
# 4      Auckland (Auckland) 1966-01-02   Minimum         17.1 -37.00813
# ...                    ...        ...       ...          ...       ...
# 62452  Auckland (Auckland) 2022-12-30   Minimum         19.1 -37.00813
# 62453  Auckland (Auckland) 2022-12-30   Average         21.6 -37.00813
# 62454  Auckland (Auckland) 2022-12-31   Maximum         25.2 -37.00813
# 62455  Auckland (Auckland) 2022-12-31   Minimum         17.4 -37.00813
# 62456  Auckland (Auckland) 2022-12-31   Average         21.3 -37.00813
#
#              lon
# 0      174.78873
# 1      174.78873
# 2      174.78873
# 3      174.78873
# 4      174.78873
# ...          ...
# 62452  174.78873
# 62453  174.78873
# 62454  174.78873
# 62455  174.78873
# 62456  174.78873
#
# [62457 rows x 6 columns]

# %% [markdown]
# # Seperate the statistic column, convert from multiple rows to multiple columns

# %%
pivoted_df = aucklandTemp.pivot(index=['date'], columns='statistic', values='temperature')
pivoted_df
# Out:
# statistic   Average  Maximum  Minimum
# date
# 1966-01-01     18.0     22.2     13.9
# 1966-01-02     20.5     23.9     17.1
# 1966-01-03     20.3     23.5     17.1
# 1966-01-04     20.3     24.4     16.2
# 1966-01-05     20.6     23.4     17.8
# ...             ...      ...      ...
# 2022-12-27     21.0     25.1     17.0
# 2022-12-28     22.4     26.7     18.1
# 2022-12-29     21.8     25.1     18.6
# 2022-12-30     21.6     24.0     19.1
# 2022-12-31     21.3     25.2     17.4
#
# [20819 rows x 3 columns]

# %%
aucklandRain = rain[rain['site'] == 'Auckland (Auckland)']
aucklandRain
# Out:
#                       site       date  rainfall rainfall_units       lat  \
# 0      Auckland (Auckland) 1960-01-01       0.0             mm -37.00813
# 1      Auckland (Auckland) 1960-01-02       0.0             mm -37.00813
# 2      Auckland (Auckland) 1960-01-03       9.2             mm -37.00813
# 3      Auckland (Auckland) 1960-01-04       0.0             mm -37.00813
# 4      Auckland (Auckland) 1960-01-05       0.0             mm -37.00813
# ...                    ...        ...       ...            ...       ...
# 23006  Auckland (Auckland) 2022-12-27       0.0             mm -37.00813
# 23007  Auckland (Auckland) 2022-12-28       0.0             mm -37.00813
# 23008  Auckland (Auckland) 2022-12-29       0.0             mm -37.00813
# 23009  Auckland (Auckland) 2022-12-30       0.0             mm -37.00813
# 23010  Auckland (Auckland) 2022-12-31       0.8             mm -37.00813
#
#              lon
# 0      174.78873
# 1      174.78873
# 2      174.78873
# 3      174.78873
# 4      174.78873
# ...          ...
# 23006  174.78873
# 23007  174.78873
# 23008  174.78873
# 23009  174.78873
# 23010  174.78873
#
# [23011 rows x 6 columns]

# %% [markdown]
# # Merge Rainfall data, and Temperature data

# %%
auckland = aucklandRain.merge(pivoted_df, on='date')
auckland.head(10)
# Out:
#                   site       date  rainfall rainfall_units       lat  \
# 0  Auckland (Auckland) 1966-01-01       0.0             mm -37.00813
# 1  Auckland (Auckland) 1966-01-02      26.2             mm -37.00813
# 2  Auckland (Auckland) 1966-01-03       0.0             mm -37.00813
# 3  Auckland (Auckland) 1966-01-04       0.0             mm -37.00813
# 4  Auckland (Auckland) 1966-01-05       1.3             mm -37.00813
# 5  Auckland (Auckland) 1966-01-06       8.9             mm -37.00813
# 6  Auckland (Auckland) 1966-01-07       5.1             mm -37.00813
# 7  Auckland (Auckland) 1966-01-08       1.3             mm -37.00813
# 8  Auckland (Auckland) 1966-01-09       2.5             mm -37.00813
# 9  Auckland (Auckland) 1966-01-10       0.0             mm -37.00813
#
#          lon  Average  Maximum  Minimum
# 0  174.78873     18.0     22.2     13.9
# 1  174.78873     20.5     23.9     17.1
# 2  174.78873     20.3     23.5     17.1
# 3  174.78873     20.3     24.4     16.2
# 4  174.78873     20.6     23.4     17.8
# 5  174.78873     21.0     23.4     18.6
# 6  174.78873     20.0     23.7     16.3
# 7  174.78873     19.7     22.1     17.3
# 8  174.78873     17.8     19.7     15.9
# 9  174.78873     16.2     18.0     14.4

# %%
auckland.rename(columns={"rainfall": 'rainfall(mm)',  "Average" : 'tavg', 'Maximum': 'tmax', 'Minimum': 'tmin' }, inplace=True)
auckland
# Out:
#                       site       date  rainfall(mm) rainfall_units       lat  \
# 0      Auckland (Auckland) 1966-01-01           0.0             mm -37.00813
# 1      Auckland (Auckland) 1966-01-02          26.2             mm -37.00813
# 2      Auckland (Auckland) 1966-01-03           0.0             mm -37.00813
# 3      Auckland (Auckland) 1966-01-04           0.0             mm -37.00813
# 4      Auckland (Auckland) 1966-01-05           1.3             mm -37.00813
# ...                    ...        ...           ...            ...       ...
# 20814  Auckland (Auckland) 2022-12-27           0.0             mm -37.00813
# 20815  Auckland (Auckland) 2022-12-28           0.0             mm -37.00813
# 20816  Auckland (Auckland) 2022-12-29           0.0             mm -37.00813
# 20817  Auckland (Auckland) 2022-12-30           0.0             mm -37.00813
# 20818  Auckland (Auckland) 2022-12-31           0.8             mm -37.00813
#
#              lon  tavg  tmax  tmin
# 0      174.78873  18.0  22.2  13.9
# 1      174.78873  20.5  23.9  17.1
# 2      174.78873  20.3  23.5  17.1
# 3      174.78873  20.3  24.4  16.2
# 4      174.78873  20.6  23.4  17.8
# ...          ...   ...   ...   ...
# 20814  174.78873  21.0  25.1  17.0
# 20815  174.78873  22.4  26.7  18.1
# 20816  174.78873  21.8  25.1  18.6
# 20817  174.78873  21.6  24.0  19.1
# 20818  174.78873  21.3  25.2  17.4
#
# [20819 rows x 9 columns]

# %%
auckland.drop(columns=['site','rainfall_units', 'lat', 'lon'], inplace=True)
auckland
# Out:
#             date  rainfall(mm)  tavg  tmax  tmin
# 0     1966-01-01           0.0  18.0  22.2  13.9
# 1     1966-01-02          26.2  20.5  23.9  17.1
# 2     1966-01-03           0.0  20.3  23.5  17.1
# 3     1966-01-04           0.0  20.3  24.4  16.2
# 4     1966-01-05           1.3  20.6  23.4  17.8
# ...          ...           ...   ...   ...   ...
# 20814 2022-12-27           0.0  21.0  25.1  17.0
# 20815 2022-12-28           0.0  22.4  26.7  18.1
# 20816 2022-12-29           0.0  21.8  25.1  18.6
# 20817 2022-12-30           0.0  21.6  24.0  19.1
# 20818 2022-12-31           0.8  21.3  25.2  17.4
#
# [20819 rows x 5 columns]

# %%
filepath = 'data/auckland_rain_temp_statsNZ.csv'
auckland.to_csv(filepath, index=False)

# %%
auckland.isnull().value_counts()
# Out:
# date   rainfall(mm)  tavg   tmax   tmin
# False  False         False  False  False    20819
# dtype: int64

# %%
auckland.isnull().value_counts()
# Out:
# date   rainfall(mm)  tavg   tmax   tmin
# False  False         False  False  False    20819
# dtype: int64

# %%
auckland.head()
# Out:
#         date  rainfall(mm)  tavg  tmax  tmin
# 0 1966-01-01           0.0  18.0  22.2  13.9
# 1 1966-01-02          26.2  20.5  23.9  17.1
# 2 1966-01-03           0.0  20.3  23.5  17.1
# 3 1966-01-04           0.0  20.3  24.4  16.2
# 4 1966-01-05           1.3  20.6  23.4  17.8

# %%
drought = pd.read_csv('data/statsNZ/drought-data-to-2022-statsnz/drought-spei-1962-2022.csv')

# Convert 'year' and 'month' columns to strings
drought['year'] = drought['year'].astype(str)
drought['month'] = drought['month'].astype(str)

# Merge the drought data with the Auckland weather data based on the "date" column
drought['date'] = pd.to_datetime(drought['year'] + '-' + drought['month'])
drought.head()
# Out:
#                   site  id  year month  time_scale          drought_type  \
# 0  Auckland (Auckland)   1  1966    12          12  Hydrological drought
# 1  Auckland (Auckland)   1  1967     1          12  Hydrological drought
# 2  Auckland (Auckland)   1  1967     2          12  Hydrological drought
# 3  Auckland (Auckland)   1  1967     3          12  Hydrological drought
# 4  Auckland (Auckland)   1  1967     4          12  Hydrological drought
#
#        spei    spei_class  imputed_value      drought_event  duration  \
# 0  1.393009  Moderate wet          False  Non-drought event       NaN
# 1  1.303403  Moderate wet          False  Non-drought event       NaN
# 2  1.450834  Moderate wet          False  Non-drought event       NaN
# 3  2.206351   Extreme wet          False  Non-drought event       NaN
# 4  1.932205    Severe wet          False  Non-drought event       NaN
#
#   start_event  severity  intensity       lat        lon    region       date
# 0   Dec, 1966       NaN        NaN -37.00813  174.78873  Auckland 1966-12-01
# 1   Dec, 1966       NaN        NaN -37.00813  174.78873  Auckland 1967-01-01
# 2   Dec, 1966       NaN        NaN -37.00813  174.78873  Auckland 1967-02-01
# 3   Dec, 1966       NaN        NaN -37.00813  174.78873  Auckland 1967-03-01
# 4   Dec, 1966       NaN        NaN -37.00813  174.78873  Auckland 1967-04-01

# %%
rain_drought = pd.merge(auckland, drought, on='date', how='inner')
# missing value

# %%
# Drop duplicate columns and unnecessary columns
rain_drought = rain_drought.drop(columns=['site','id', 'year', 'month', 'time_scale','lat', 'lon', 'region'])
rain_drought.head()
# Out:
#         date  rainfall(mm)  tavg  tmax  tmin            drought_type  \
# 0 1966-01-01           0.0  18.0  22.2  13.9    Hydrological drought
# 1 1966-01-01           0.0  18.0  22.2  13.9  Meteorological drought
# 2 1966-01-01           0.0  18.0  22.2  13.9    Agricultural drought
# 3 1966-01-01           0.0  18.0  22.2  13.9    Hydrological drought
# 4 1966-01-01           0.0  18.0  22.2  13.9  Meteorological drought
#
#        spei        spei_class  imputed_value      drought_event  duration  \
# 0  0.858951  Moderate climate          False  Non-drought event      52.0
# 1  0.314179  Moderate climate          False  Non-drought event      18.0
# 2  0.188727  Moderate climate          False  Non-drought event      18.0
# 3  1.438625      Moderate wet          False  Non-drought event       NaN
# 4  0.888446  Moderate climate          False  Non-drought event      35.0
#
#   start_event  severity  intensity
# 0   Mar, 1965       NaN        NaN
# 1   Jan, 1965       NaN        NaN
# 2   Mar, 1965       NaN        NaN
# 3   Dec, 1960       NaN        NaN
# 4   Jul, 1964       NaN        NaN
