# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import sklearn as sk
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rainfall = pd.read_csv("data/niwaDailyData/RainDaily.csv")
rainfall.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 rainfall = pd.read_csv("data/niwaDailyData/RainDaily.csv")
#       2 rainfall.head()
#
# File c:\Users\Ying\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Ying\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\Ying\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Ying\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\Ying\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/niwaDailyData/RainDaily.csv'

# %%
# rainfall = rainfall.drop(['Station', 'SofG'], axis=1)
rainfall['Date(NZST)'] = pd.to_datetime(rainfall['Date(NZST)'], format='%Y%m%d:%H%M')
rainfall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5352 entries, 0 to 5351
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Station      5352 non-null   int64
#  1   Date(NZST)   5352 non-null   datetime64[ns]
#  2   Amount(mm)   5352 non-null   float64
#  3   SofG         5352 non-null   object
#  4   Deficit(mm)  5352 non-null   float64
#  5   Runoff(mm)   5352 non-null   float64
#  6   Period(Hrs)  5352 non-null   int64
#  7   Freq         5352 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(2)
# memory usage: 334.6+ KB

# %%
rainfall.plot(style="." , figsize=(15,8), xlabel = "Period", ylabel = "mm")
# Out:
# <Axes: xlabel='Period', ylabel='mm'>

# %%
rainfall_f = rainfall.filter(['Amount(mm)', 'Deficit(mm)', 'Runoff(mm)'], axis=1 )
print("Precipitation vs Selected Attributes Graph")
for i in range (rainfall_f.columns.size):
    plt.subplot(3,2, i+1)
    plt.scatter("Period(Hrs)", rainfall_f[rainfall_f.values[i][:100]])
    plt.show()
rainfall.plot(subplots=True, layout=(2,2), figsize=(20,8))
# Out:
# Precipitation vs Selected Attributes Graph
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 5
#       3 for i in range (rainfall_f.columns.size):
#       4     plt.subplot(3,2, i+1)
# ----> 5     plt.scatter("Period(Hrs)", rainfall_f[rainfall_f.values[i][:100]])
#       6     plt.show()
#       7 rainfall.plot(subplots=True, layout=(2,2), figsize=(20,8))
#
# File c:\Users\Ying\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3902, in DataFrame.__getitem__(self, key)
#    3900     if is_iterator(key):
#    3901         key = list(key)
# -> 3902     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3904 # take() does not accept boolean indexers
#    3905 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\Ying\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
#    6117 if isinstance(key, Index):
#    6118     # GH 42790 - Preserve name from an Index
#
# File c:\Users\Ying\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6175, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6173     if use_interval_msg:
#    6174         key = list(key)
# -> 6175     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6178 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([25.0, 15.5, 0.0], dtype='float64')] are in the [columns]"

# %%
correlation_matrix = rainfall.corr()
plt.scatter(rainfall["Amount(mm)"], rainfall["Deficit(mm)"], rainfall["Runoff(mm)"], rainfall["Period(Hrs)"])
# Out:
# /tmp/ipykernel_1000/1056539661.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = rainfall.corr()

# %%
correlation_matrix["Amount(mm)"]
# Out:
# Amount(mm)     1.000000
# Deficit(mm)   -0.185437
# Runoff(mm)     0.852161
# Period(Hrs)         NaN
# Name: Amount(mm), dtype: float64

# %%
pressure_df = pd.read_csv('./cliflow_Niwa_Auckland_data/Pressure_9am_only.csv')
pressure_df = pressure_df.drop(['Station', 'tend', 'amt(hPa)', 'a24(hPa)'], axis=1)
pressure_df.head()
pd.merge(pressure_df, rainfall)
# Out:
#          Date(NZST)  Pmsl(hPa) Pstn(hPa)  Amount(mm)  Deficit(mm)  Runoff(mm)  \
# 0     20090101:0800     1007.0     983.6        25.0         15.5         0.0
# 1     20090102:0800     1012.3     988.5         0.2         19.6         0.0
# 2     20090103:0800     1009.0     985.5        38.4          0.0        14.5
# 3     20090104:0800     1022.2     998.1         0.6          3.7         0.0
# 4     20090105:0800     1022.5     998.6         0.0          8.1         0.0
# ...             ...        ...       ...         ...          ...         ...
# 5346  20230823:0900     1029.1    1004.5         0.0          2.1         0.0
# 5347  20230824:0900     1027.2    1002.7         0.0          3.2         0.0
# 5348  20230825:0900     1028.0    1003.3         0.0          4.2         0.0
# 5349  20230826:0900     1024.9    1000.5         0.0          5.3         0.0
# 5350  20230827:0900     1021.2       997         1.2          5.2         0.0
#
#       Period(Hrs) Freq
# 0              24    D
# 1              24    D
# 2              24    D
# 3              24    D
# 4              24    D
# ...           ...  ...
# 5346           24    D
# 5347           24    D
# 5348           24    D
# 5349           24    D
# 5350           24    D
#
# [5351 rows x 8 columns]

# %%
radiation_df = pd.read_csv('./cliflow_Niwa_Auckland_data/Radiation_Daily_Global.csv').drop(['Station'], axis=1)

rainbreakpoint_df = pd.read_csv("./cliflow_Niwa_Auckland_data/RainBreakpointsfromRainRate.csv").drop(['Station'], axis=1)
rainfall_df = pd.read_csv("./cliflow_Niwa_Auckland_data/RainDaily.csv").drop(['Station'], axis=1)
soilMoisture_df = pd.read_csv('./cliflow_Niwa_Auckland_data/SoilMoisture.csv').drop(['Station'], axis=1)
sunshine_df = pd.read_csv('./cliflow_Niwa_Auckland_data/SunshineDaily.csv').drop(['Station'], axis=1)
surfaceWind_df = pd.read_csv('./cliflow_Niwa_Auckland_data/SurfaceWind9am.csv').drop(['Station'], axis=1)
temperature_df = pd.read_csv('./cliflow_Niwa_Auckland_data/TemperatureMaxMinDaily.csv').drop(['Station'], axis=1)
observationAirTemperature_df = pd.read_csv('./cliflow_Niwa_Auckland_data/TemperatureScreenObs9amOnly.csv').drop(['Station'], axis=1)
windMaxGust_df = pd.read_csv('./cliflow_Niwa_Auckland_data/WindMaxGustDaily.csv').drop(['Station'], axis=1)

merged_df = [radiation_df, rainbreakpoint_df, rainfall_df, soilMoisture_df, sunshine_df, surfaceWind_df, temperature_df, observationAirTemperature_df, windMaxGust_df]
joindata = pd.concat(merged_df, join='outer', axis=1)
joindata.drop_duplicates() 
joindata.head()
# Out:
#       Date(NZST)  Amount(MJ/m2)  Period(Hrs) Type Freq Date(NZST)_Incl_secs  \
# 0  20090719:2359           3.85         24.0    G    D      20090101:000830
# 1  20090720:2359           4.64         24.0    G    D      20090101:002330
# 2  20090721:2359           1.87         24.0    G    D      20090101:011112
# 3  20090722:2359           3.23         24.0    G    D      20090101:012236
# 4  20090723:2359           0.77         24.0    G    D      20090101:020436
#
#   Amount(mm)  Period(min) Freq     Date(NZST)  ...  Unnamed: 7 Unnamed: 8  \
# 0          0          8.5  BPS  20090101:0800  ...         NaN        NaN
# 1       0.16         15.0  BPS  20090102:0800  ...         NaN        NaN
# 2          0         47.7  BPS  20090103:0800  ...         NaN        NaN
# 3       0.12         11.4  BPS  20090104:0800  ...         NaN        NaN
# 4          0         42.0  BPS  20090105:0800  ...         NaN        NaN
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11     Date(NZST) Dir(DegT)  Speed(m/s)  \
# 0         NaN          NaN          NaN  20090101:2259       275         9.3
# 1         NaN          NaN          NaN  20090102:2259        44        11.8
# 2         NaN          NaN          NaN  20090103:2259        13        11.8
# 3         NaN          NaN          NaN  20090104:2259       190         7.7
# 4         NaN          NaN          NaN  20090105:2259       185         7.2
#
#    Period(Hrs) Freq
# 0         24.0    D
# 1         24.0    D
# 2         24.0    D
# 3         24.0    D
# 4         24.0    D
#
# [5 rows x 57 columns]

# %%
joindata.index = pd.to_datetime(joindata.index)
joindata.plot( figsize=(20,8))
# Out:
# <Axes: >

# %%
correlation = joindata.corr()
correlation
# Out:
# /tmp/ipykernel_1000/3782272016.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = joindata.corr()
#                Amount(MJ/m2)  Period(Hrs)  Period(min)  Amount(mm)  \
# Amount(MJ/m2)       1.000000          NaN    -0.046623    0.005649
# Period(Hrs)              NaN          NaN          NaN         NaN
# Period(min)        -0.046623          NaN     1.000000   -0.004822
# Amount(mm)          0.005649          NaN    -0.004822    1.000000
# Deficit(mm)         0.126762          NaN    -0.003175   -0.185437
# Runoff(mm)          0.011880          NaN     0.000203    0.852161
# Period(Hrs)              NaN          NaN          NaN         NaN
# Percent(%)         -0.120792          NaN    -0.000977    0.017424
# Depth(cm)                NaN          NaN          NaN         NaN
# Amount(Hrs)        -0.101393          NaN     0.022161   -0.128214
# Period(Hrs)              NaN          NaN          NaN         NaN
# Dir(DegT)          -0.039759          NaN    -0.001034   -0.049708
# Speed(m/s)         -0.091473          NaN     0.007069    0.116329
# Dir StdDev         -0.109348          NaN     0.012651    0.047905
# Spd StdDev         -0.097511          NaN     0.001736    0.130204
# Period(Hrs)              NaN          NaN          NaN         NaN
# Speed(m/s)         -0.234788          NaN     0.000978    0.066125
# Period(Hrs)              NaN          NaN          NaN         NaN
#
#                Deficit(mm)  Runoff(mm)  Period(Hrs)  Percent(%)  Depth(cm)  \
# Amount(MJ/m2)     0.126762    0.011880          NaN   -0.120792        NaN
# Period(Hrs)            NaN         NaN          NaN         NaN        NaN
# Period(min)      -0.003175    0.000203          NaN   -0.000977        NaN
# Amount(mm)       -0.185437    0.852161          NaN    0.017424        NaN
# Deficit(mm)       1.000000   -0.235970          NaN   -0.021683        NaN
# Runoff(mm)       -0.235970    1.000000          NaN    0.022555        NaN
# Period(Hrs)            NaN         NaN          NaN         NaN        NaN
# Percent(%)       -0.021683    0.022555          NaN    1.000000        NaN
# Depth(cm)              NaN         NaN          NaN         NaN        NaN
# Amount(Hrs)       0.268133   -0.149050          NaN    0.051399        NaN
# Period(Hrs)            NaN         NaN          NaN         NaN        NaN
# Dir(DegT)         0.025008   -0.037400          NaN    0.031487        NaN
# Speed(m/s)       -0.004513    0.067108          NaN   -0.016310        NaN
# Dir StdDev        0.013579    0.026328          NaN    0.143563        NaN
# Spd StdDev       -0.007361    0.075251          NaN    0.007991        NaN
# Period(Hrs)            NaN         NaN          NaN         NaN        NaN
# Speed(m/s)        0.079899    0.002551          NaN    0.044227        NaN
# Period(Hrs)            NaN         NaN          NaN         NaN        NaN
#
#                Amount(Hrs)  Period(Hrs)  Dir(DegT)  Speed(m/s)  Dir StdDev  \
# Amount(MJ/m2)    -0.101393          NaN  -0.039759   -0.091473   -0.109348
# Period(Hrs)            NaN          NaN        NaN         NaN         NaN
# Period(min)       0.022161          NaN  -0.001034    0.007069    0.012651
# Amount(mm)       -0.128214          NaN  -0.049708    0.116329    0.047905
# Deficit(mm)       0.268133          NaN   0.025008   -0.004513    0.013579
# Runoff(mm)       -0.149050          NaN  -0.037400    0.067108    0.026328
# Period(Hrs)            NaN          NaN        NaN         NaN         NaN
# Percent(%)        0.051399          NaN   0.031487   -0.016310    0.143563
# Depth(cm)              NaN          NaN        NaN         NaN         NaN
# Amount(Hrs)       1.000000          NaN   0.033344   -0.006416    0.068599
# Period(Hrs)            NaN          NaN        NaN         NaN         NaN
# Dir(DegT)         0.033344          NaN   1.000000   -0.329388    0.009680
# Speed(m/s)       -0.006416          NaN  -0.329388    1.000000   -0.088174
# Dir StdDev        0.068599          NaN   0.009680   -0.088174    1.000000
# Spd StdDev       -0.042960          NaN  -0.291194    0.859663    0.075179
# Period(Hrs)            NaN          NaN        NaN         NaN         NaN
# Speed(m/s)        0.087795          NaN  -0.020998    0.155053    0.106408
# Period(Hrs)            NaN          NaN        NaN         NaN         NaN
#
#                Spd StdDev  Period(Hrs)  Speed(m/s)  Period(Hrs)
# Amount(MJ/m2)   -0.097511          NaN   -0.234788          NaN
# Period(Hrs)           NaN          NaN         NaN          NaN
# Period(min)      0.001736          NaN    0.000978          NaN
# Amount(mm)       0.130204          NaN    0.066125          NaN
# Deficit(mm)     -0.007361          NaN    0.079899          NaN
# Runoff(mm)       0.075251          NaN    0.002551          NaN
# Period(Hrs)           NaN          NaN         NaN          NaN
# Percent(%)       0.007991          NaN    0.044227          NaN
# Depth(cm)             NaN          NaN         NaN          NaN
# Amount(Hrs)     -0.042960          NaN    0.087795          NaN
# Period(Hrs)           NaN          NaN         NaN          NaN
# Dir(DegT)       -0.291194          NaN   -0.020998          NaN
# Speed(m/s)       0.859663          NaN    0.155053          NaN
# Dir StdDev       0.075179          NaN    0.106408          NaN
# Spd StdDev       1.000000          NaN    0.171418          NaN
# Period(Hrs)           NaN          NaN         NaN          NaN
# Speed(m/s)       0.171418          NaN    1.000000          NaN
# Period(Hrs)           NaN          NaN         NaN          NaN

# %%
# import modules
import matplotlib.pyplot as mp
import pandas as pd
import seaborn as sb


# joindata.drop('Period(Hrs)')
# plotting correlation heatmap
dataplot = sns.heatmap(correlation, annot=True, cmap="coolwarm")
  
# displaying heatmap
mp.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       4 import seaborn as sb
#       7 # joindata.drop('Period(Hrs)')
#       8 # plotting correlation heatmap
# ----> 9 dataplot = sns.heatmap(correlation, annot=True, cmap="coolwarm")
#      11 # displaying heatmap
#      12 mp.show()
#
# NameError: name 'sns' is not defined
