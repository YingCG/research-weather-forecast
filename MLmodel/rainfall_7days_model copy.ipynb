# %%
#run in python 3.10.7 on windows

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

auckland_rain = pd.read_csv('../data/NOAAdata/Auckland_NOAA.csv')
auckland_rain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10521 entries, 0 to 10520
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  10521 non-null  object
#  1   NAME     10521 non-null  object
#  2   DATE     10521 non-null  object
#  3   PRCP     9020 non-null   float64
#  4   TAVG     10521 non-null  int64
#  5   TMAX     7259 non-null   float64
#  6   TMIN     4791 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 575.5+ KB

# %%
# Step 1: Summary Statistics
print(auckland_rain.describe())
# Out:
#               PRCP          TAVG         TMAX         TMIN
# count  9020.000000  10521.000000  7259.000000  4791.000000
# mean      0.118242     59.892406    67.140929    53.045919
# std       0.294766      6.478498     6.933857     7.176043
# min       0.000000     41.000000    47.000000    32.000000
# 25%       0.000000     55.000000    62.000000    48.000000
# 50%       0.000000     60.000000    67.000000    53.000000
# 75%       0.100000     65.000000    73.000000    59.000000
# max       9.390000     77.000000    86.000000    72.000000

# %%
# Step 2: Data Visualization

# Time series plot of rainfall
plt.figure(figsize=(12, 6))
plt.plot(auckland_rain['DATE'], auckland_rain['PRCP'], label='Rainfall')
plt.xlabel('Date')
plt.ylabel('Rainfall(mm)')
plt.title('Rainfall Over Time')
plt.legend()
plt.show()

# %%
# Histograms
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.histplot(data=auckland_rain, x='rainfall(mm)', bins=30, kde=True)
plt.xlabel('Rainfall (mm)')
plt.title('Distribution of Rainfall')
plt.show()

# %%
# Scatterplot
plt.figure(figsize=(8, 8))
sns.scatterplot(data=auckland_rain, x='tavg', y='rainfall(mm)')
plt.xlabel('Average Temperature (°C)')
plt.ylabel('Rainfall (mm)')
plt.title('Scatterplot of Temperature vs. Rainfall')
plt.show()

# %%
# Handling Missing Data
missing_data = auckland_rain.isnull().sum()
print(missing_data)
# Out:
# date            0
# rainfall(mm)    0
# tavg            0
# tmax            0
# tmin            0
# dtype: int64

# %%
# Correlation Analysis
correlation_matrix = auckland_rain.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
